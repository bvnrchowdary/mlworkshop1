# %% [markdown]
# ### Pandas
# - DataFrame
#     - it is a tuple witg multiple rowrs and columns
#     - it can read differnt types of files
#     - example: csv,excel,html,json

# %%
import pandas as pd

# %%
pd.Series([1,2,3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
# creatingt a dataframe
d1=pd.DataFrame([1,2,3,4])
d1
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
d2=pd.DataFrame([["apssdc",22,2021],["workshop",5,2021]])
d2
# Out:
#           0   1     2
# 0    apssdc  22  2021
# 1  workshop   5  2021

# %%
d2=pd.DataFrame([["apssdc",22,2021],["workshop",5,2021]],columns = ("name","date","year"),index=["a","b"])

# %%
d2
# Out:
#        name  date  year
# a    apssdc    22  2021
# b  workshop     5  2021

# %%
dict1={"Name":["apssdc","workshop"],"date":[22,5],"year":[2021,2020]}
dict1
# Out:
# {'Name': ['apssdc', 'workshop'], 'date': [22, 5], 'year': [2021, 2020]}

# %%
d3=pd.DataFrame(dict1,index=["a","b"])
d3
# Out:
#        Name  date  year
# a    apssdc    22  2021
# b  workshop     5  2020

# %%
d3.index
# Out:
# Index(['a', 'b'], dtype='object')

# %%
d3.columns
# Out:
# Index(['Name', 'date', 'year'], dtype='object')

# %%
d3.shape
# Out:
# (2, 3)

# %% [markdown]
# ### Acessing the elements

# %%
d3["Name"] # getting columns
# Out:
# a      apssdc
# b    workshop
# Name: Name, dtype: object

# %%
d3["Name"]["b"]
# Out:
# 'workshop'

# %%
d3["Name"]["a"]
# Out:
# 'apssdc'

# %%
d3["year"]["b"]
# Out:
# 2020

# %%
d3["date"][0]
# Out:
# 22

# %%
d3[-1:]
# Out:
#        Name  date  year
# b  workshop     5  2020

# %%
d3[:1]
# Out:
#      Name  date  year
# a  apssdc    22  2021

# %% [markdown]
# ## Load DataSet

# %%
data=pd.read_csv("market.csv")

# %%
data
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# 1                 13     4.56           0.93                 0.54
# 2                 26  1148.90           2.50                 0.59
# 3                 43   729.34          14.30                 0.37
# 4                 35  1219.87          26.30                 0.38
# ...              ...      ...            ...                  ...
# 8394              28   374.63           7.69                 0.59
# 8395              20   -74.03           6.92                 0.37
# 8396              39   -70.85           5.35                 0.40
# 8397              23   565.34          30.00                 0.62
# 8398              47   131.39           4.86                 0.38
#
# [8399 rows x 10 columns]

# %%
data.shape
# Out:
# (8399, 10)

# %%
data.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
data.tail(3)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.05      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.87      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.69      0.00
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 8396              39  -70.85           5.35                 0.40
# 8397              23  565.34          30.00                 0.62
# 8398              47  131.39           4.86                 0.38

# %%
data.sample(4)
# Out:
#         Ord_id Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 3990   Ord_168  Prod_4   SHP_228    Cust_61   2631.107      0.00
# 1306  Ord_5083  Prod_4  SHP_7098  Cust_1719   2403.137      0.00
# 1448  Ord_2673  Prod_1  SHP_3661  Cust_1027  21337.270      0.02
# 8117  Ord_4148  Prod_8  SHP_5780  Cust_1420     46.860      0.06
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 3990              16   297.11          13.99                 0.57
# 1306              22   377.62           8.99                 0.57
# 1448              49  7606.00          19.99                 0.58
# 8117              27   -37.08           1.99                 0.51

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8399, step=1)

# %% [markdown]
# ### Statical Analysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ord_id               8399 non-null   object
#  1   Prod_id              8399 non-null   object
#  2   Ship_id              8399 non-null   object
#  3   Cust_id              8399 non-null   object
#  4   Sales                8399 non-null   float64
#  5   Discount             8399 non-null   float64
#  6   Order_Quantity       8399 non-null   int64
#  7   Profit               8399 non-null   float64
#  8   Shipping_Cost        8399 non-null   float64
#  9   Product_Base_Margin  8336 non-null   float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 656.3+ KB

# %%
data.describe()
# Out:
#               Sales     Discount  Order_Quantity        Profit  Shipping_Cost  \
# count   8399.000000  8399.000000     8399.000000   8399.000000    8399.000000
# mean    1775.878179     0.049671       25.571735    181.184424      12.838557
# std     3585.050525     0.031823       14.481071   1196.653371      17.264052
# min        2.240000     0.000000        1.000000 -14140.700000       0.490000
# 25%      143.195000     0.020000       13.000000    -83.315000       3.300000
# 50%      449.420000     0.050000       26.000000     -1.500000       6.070000
# 75%     1709.320000     0.080000       38.000000    162.750000      13.990000
# max    89061.050000     0.250000       50.000000  27220.690000     164.730000
#
#        Product_Base_Margin
# count          8336.000000
# mean              0.512513
# std               0.135589
# min               0.350000
# 25%               0.380000
# 50%               0.520000
# 75%               0.590000
# max               0.850000

# %%
# selecting rows

# %%
data[10:20]
# Out:
#       Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 10  Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.010      0.01
# 11  Ord_1925   Prod_6  SHP_2637   Cust_708    465.900      0.05
# 12  Ord_2978  Prod_16  SHP_4112  Cust_1088    305.050      0.04
# 13  Ord_2207  Prod_11  SHP_3093   Cust_839   3364.248      0.10
# 14  Ord_2207  Prod_10  SHP_3006   Cust_839   1410.930      0.08
# 15  Ord_2280   Prod_5  SHP_3114   Cust_839    460.690      0.06
# 16  Ord_2282   Prod_9  SHP_3122   Cust_839    443.460      0.06
# 17  Ord_4471  Prod_15  SHP_6228  Cust_1521  13255.930      0.02
# 18  Ord_4427   Prod_6  SHP_6171  Cust_1521    283.130      0.08
# 19   Ord_996  Prod_13  SHP_1378   Cust_371     41.970      0.05
#
#     Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 10              43  1675.98           0.99                 0.56
# 11              38    79.34           4.86                 0.38
# 12              27    23.12           3.37                 0.57
# 13              15  -693.23          61.76                 0.78
# 14              10  -317.48          36.09                 0.77
# 15              48  -103.48           7.29                 0.45
# 16              30   193.12           1.39                 0.38
# 17              25  4089.27          26.00                 0.60
# 18              45  -141.26           6.81                 0.36
# 19              12   -37.03           4.20                 0.56

# %%
data[10:21:2]
# Out:
#       Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 10  Ord_4743   Prod_2  SHP_6615  Cust_1641  4072.01      0.01              43
# 12  Ord_2978  Prod_16  SHP_4112  Cust_1088   305.05      0.04              27
# 14  Ord_2207  Prod_10  SHP_3006   Cust_839  1410.93      0.08              10
# 16  Ord_2282   Prod_9  SHP_3122   Cust_839   443.46      0.06              30
# 18  Ord_4427   Prod_6  SHP_6171  Cust_1521   283.13      0.08              45
# 20   Ord_996  Prod_13  SHP_1378   Cust_371    57.17      0.08              18
#
#      Profit  Shipping_Cost  Product_Base_Margin
# 10  1675.98           0.99                 0.56
# 12    23.12           3.37                 0.57
# 14  -317.48          36.09                 0.77
# 16   193.12           1.39                 0.38
# 18  -141.26           6.81                 0.36
# 20   -24.03           2.31                 0.56

# %%
# selecting columns

# %%
data["Sales"]
# Out:
# 0        136.8100
# 1         42.2700
# 2       4701.6900
# 3       2337.8900
# 4       4233.1500
#           ...
# 8394    2841.4395
# 8395     127.1600
# 8396     243.0500
# 8397    3872.8700
# 8398     603.6900
# Name: Sales, Length: 8399, dtype: float64

# %%
data["Sales"].head()
# Out:
# 0     136.81
# 1      42.27
# 2    4701.69
# 3    2337.89
# 4    4233.15
# Name: Sales, dtype: float64

# %%
data[["Sales","Profit","Discount"]].head()
# Out:
#      Sales   Profit  Discount
# 0   136.81   -30.51      0.01
# 1    42.27     4.56      0.01
# 2  4701.69  1148.90      0.00
# 3  2337.89   729.34      0.09
# 4  4233.15  1219.87      0.08

# %%
data[["Sales","Profit","Discount"]].head().isnull()
# Out:
#    Sales  Profit  Discount
# 0  False   False     False
# 1  False   False     False
# 2  False   False     False
# 3  False   False     False
# 4  False   False     False

# %%
data.isnull().sum()
# Out:
# Ord_id                  0
# Prod_id                 0
# Ship_id                 0
# Cust_id                 0
# Sales                   0
# Discount                0
# Order_Quantity          0
# Profit                  0
# Shipping_Cost           0
# Product_Base_Margin    63
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 63

# %% [markdown]
# ### iloc and loc
# - iloc  --> Position based index
# - loc  --> Label based index

# %%
data.iloc[1000] # 1000 row data
# Out:
# Ord_id                 Ord_1895
# Prod_id                  Prod_4
# Ship_id                SHP_2601
# Cust_id                Cust_686
# Sales                   2433.55
# Discount                   0.05
# Order_Quantity               23
# Profit                   355.93
# Shipping_Cost              8.08
# Product_Base_Margin        0.57
# Name: 1000, dtype: object

# %%
data.iloc[1000:2000]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 1000  Ord_1895   Prod_4  SHP_2601   Cust_686  2433.550      0.05
# 1001  Ord_1910   Prod_8  SHP_3095   Cust_891   587.200      0.08
# 1002  Ord_1910  Prod_12  SHP_3096   Cust_891   110.790      0.05
# 1003  Ord_2025   Prod_6  SHP_2769   Cust_897   162.390      0.10
# 1004    Ord_97   Prod_5   SHP_132    Cust_70   426.340      0.00
# ...        ...      ...       ...        ...       ...       ...
# 1995   Ord_727  Prod_10  SHP_7074  Cust_1723  3645.450      0.04
# 1996  Ord_5071   Prod_6  SHP_7081  Cust_1723   355.030      0.00
# 1997   Ord_727   Prod_8   SHP_992   Cust_252   302.050      0.00
# 1998  Ord_5265   Prod_4  SHP_7350  Cust_1775   994.228      0.09
# 1999  Ord_5265   Prod_2  SHP_7349  Cust_1775   174.640      0.04
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 1000              23  355.93           8.08                 0.57
# 1001              29  134.25           1.99                 0.48
# 1002              39   42.68           0.50                 0.38
# 1003              33 -101.68           5.57                 0.40
# 1004              31   73.53           5.16                 0.43
# ...              ...     ...            ...                  ...
# 1995              30 -765.50          56.70                 0.68
# 1996              50  -33.31           5.11                 0.37
# 1997               9  -58.81           6.50                 0.64
# 1998               8 -446.58           8.99                 0.58
# 1999              40 -143.23           5.15                 0.59
#
# [1000 rows x 10 columns]

# %%
data.iloc[[2,5,7,100]]
# Out:
#        Ord_id Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 2    Ord_5446  Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 5    Ord_5446  Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 7    Ord_4725  Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 100  Ord_1638  Prod_8  SHP_5892  Cust_1433   220.7900      0.00
#
#      Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 2                26  1148.90           2.50                 0.59
# 5                23   -47.64           6.15                 0.37
# 7                48  1137.91           0.99                 0.55
# 100               7   -91.51           4.00                 0.74

# %%
data.iloc[3:10,4:]
# Out:
#        Sales  Discount  Order_Quantity   Profit  Shipping_Cost  \
# 3  2337.8900      0.09              43   729.34          14.30
# 4  4233.1500      0.08              35  1219.87          26.30
# 5   164.0200      0.03              23   -47.64           6.15
# 6    14.7600      0.01               5     1.32           0.50
# 7  3410.1575      0.10              48  1137.91           0.99
# 8   162.0000      0.01              33    45.84           0.71
# 9    57.2200      0.07               8   -27.72           6.60
#
#    Product_Base_Margin
# 3                 0.37
# 4                 0.38
# 5                 0.37
# 6                 0.36
# 7                 0.55
# 8                 0.52
# 9                 0.37

# %%
data.loc[4,"Sales"]
# Out:
# 4233.15

# %%
data.loc[20,'Cust_id']
# Out:
# 'Cust_371'

# %% [markdown]
# ##### Filtering

# %%
data["Sales"]>1000
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 8394     True
# 8395    False
# 8396    False
# 8397     True
# 8398    False
# Name: Sales, Length: 8399, dtype: bool

# %%
data[data["Sales"]>5000]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 17    Ord_4471  Prod_15  SHP_6228  Cust_1521  13255.930      0.02
# 57    Ord_4546   Prod_1  SHP_6327  Cust_1474   5208.780      0.05
# 64    Ord_4475   Prod_4  SHP_6234  Cust_1474   7640.225      0.07
# 79    Ord_5188  Prod_14  SHP_7252  Cust_1749   5177.400      0.06
# 82    Ord_5156   Prod_4  SHP_7207  Cust_1749   8374.132      0.06
# ...        ...      ...       ...        ...        ...       ...
# 8317  Ord_2770   Prod_3  SHP_3802  Cust_1016   7535.960      0.08
# 8332  Ord_2101  Prod_11  SHP_2875   Cust_790  10714.780      0.00
# 8343  Ord_2178   Prod_4  SHP_2968   Cust_785   6030.580      0.09
# 8366  Ord_3593   Prod_3  SHP_4974  Cust_1274  12073.060      0.03
# 8367  Ord_3593  Prod_15  SHP_4975  Cust_1274   6685.050      0.09
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 17                25  4089.27          26.00                 0.60
# 57                34  1547.78           7.07                 0.59
# 64                46  2027.68           2.50                 0.59
# 79                12   287.50          49.00                 0.38
# 82                48  2568.10           8.99                 0.56
# ...              ...      ...            ...                  ...
# 8317              46  2745.87          19.99                 0.40
# 8332              41  -627.64          66.67                 0.65
# 8343              39  1197.86           8.99                 0.58
# 8366              39  5081.87          19.99                 0.38
# 8367              25  1653.60          24.49                  NaN
#
# [824 rows x 10 columns]

# %%
data[(data["Sales"]>20000)&(data["Profit"]>10000)]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 385   Ord_3707  Prod_17  SHP_5136  Cust_1307  28359.40      0.05
# 2253  Ord_3143  Prod_14  SHP_4362  Cust_1170  28664.52      0.09
# 2738  Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00
# 3241   Ord_118   Prod_3   SHP_161    Cust_63  23792.93      0.00
# 4124  Ord_2345   Prod_3  SHP_3218   Cust_937  25409.63      0.02
# 4399  Ord_4614  Prod_14  SHP_6423  Cust_1571  29884.60      0.05
# 5042  Ord_2425  Prod_14  SHP_3329   Cust_934  27820.34      0.08
# 5971  Ord_3059  Prod_17  SHP_4249  Cust_1143  21921.28      0.04
# 6037  Ord_3727  Prod_17  SHP_5171  Cust_1310  29186.49      0.05
# 6660  Ord_5425  Prod_14  SHP_7580  Cust_1799  27720.98      0.07
# 6765  Ord_5186  Prod_17  SHP_7247  Cust_1763  26095.13      0.03
#
#       Order_Quantity    Profit  Shipping_Cost  Product_Base_Margin
# 385               49  14440.39          24.49                 0.37
# 2253              50  13340.26          24.49                 0.37
# 2738              13  27220.69          24.49                 0.39
# 3241              18  10951.31          19.99                 0.35
# 4124              20  11535.28          19.99                 0.35
# 4399              49  12748.86          24.49                 0.44
# 5042              48  11630.15          24.49                 0.37
# 5971              43  10521.33          28.14                 0.38
# 6037              38  11562.08          55.30                 0.40
# 6660              46  11984.40          24.49                 0.37
# 6765              35  12606.81          55.30                 0.40

# %%
# Sorting
#ASending order
#descending order

# %%
data.sort_values("Sales")
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 6700   Ord_704   Prod_7   SHP_964   Cust_242      2.24      0.01
# 4631   Ord_149   Prod_3  SHP_7028  Cust_1712      3.20      0.09
# 817   Ord_4270   Prod_7  SHP_5959  Cust_1450      3.23      0.06
# 52    Ord_4755  Prod_13  SHP_6628  Cust_1579      3.41      0.06
# 384   Ord_2252   Prod_3  SHP_3064   Cust_881      3.42      0.05
# ...        ...      ...       ...        ...       ...       ...
# 4399  Ord_4614  Prod_14  SHP_6423  Cust_1571  29884.60      0.05
# 2349  Ord_2373  Prod_14  SHP_3259   Cust_942  33367.85      0.01
# 1835  Ord_3875  Prod_17  SHP_5370  Cust_1351  41343.21      0.09
# 3784  Ord_2338  Prod_17  SHP_3207   Cust_932  45923.76      0.07
# 2738  Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00
#
#       Order_Quantity    Profit  Shipping_Cost  Product_Base_Margin
# 6700               1     -1.97           0.70                 0.37
# 4631               1     -3.16           1.49                 0.37
# 817                2     -2.73           0.70                 0.81
# 52                 1     -1.78           0.70                 0.56
# 384                1     -2.91           1.49                 0.37
# ...              ...       ...            ...                  ...
# 4399              49  12748.86          24.49                 0.44
# 2349               9   3992.52          24.49                 0.37
# 1835               8   3852.19          24.49                 0.39
# 3784               7    102.61          24.49                 0.39
# 2738              13  27220.69          24.49                 0.39
#
# [8399 rows x 10 columns]

# %%
data.sort_values(by=["Prod_id"],inplace=True)

# %%
data.head()
# Out:
#         Ord_id Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 1593  Ord_1067  Prod_1  SHP_1474   Cust_397  7333.45      0.07
# 6127  Ord_1791  Prod_1  SHP_2482   Cust_838   416.40      0.02
# 4794  Ord_4923  Prod_1  SHP_6867  Cust_1681  1438.33      0.08
# 2595  Ord_4464  Prod_1  SHP_6219  Cust_1445   279.77      0.07
# 7772  Ord_3210  Prod_1  SHP_4452  Cust_1183   494.34      0.05
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 1593              27 -207.28          35.00                 0.80
# 6127              24   24.33           4.96                 0.58
# 4794              43  163.38           8.22                 0.57
# 2595               8  -14.02           8.22                 0.57
# 7772              15  -30.19           6.72                 0.75

# %%
data.sort_values(by=["Prod_id"],inplace=True,ascending=False)

# %%
data.head()
# Out:
#         Ord_id Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 8177  Ord_5166  Prod_9  SHP_7220  Cust_1755   347.84      0.00
# 975   Ord_5081  Prod_9  SHP_7094  Cust_1724   541.47      0.05
# 5300  Ord_2558  Prod_9  SHP_3500   Cust_944  1287.94      0.06
# 7955  Ord_4065  Prod_9  SHP_5669  Cust_1376   733.55      0.07
# 2506   Ord_262  Prod_9   SHP_358    Cust_66  6553.45      0.03
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 8177              37   -99.25           8.29                 0.38
# 975               49    90.62           4.80                 0.36
# 5300              37   140.35          14.72                 0.40
# 7955               8   103.13          19.99                 0.40
# 2506              39  2969.81          19.99                 0.39

# %% [markdown]
# ## Data Preprocessing with Scikit-Learn

# %% [markdown]
# - Problems :
#     - insufficent of data
#     - too much of data
#     - outliers
#     - missing data
#     - duplicate data
#
# - Scaling Techniques :
#     - standard scalar
#     - robust scalar
#     - normalization
#     - ranging scalar(Min Max Scalar)

# %% [markdown]
# ##### Standard Scalar
# - [xi-mean(x)]/std(x)]

# %%
from sklearn import preprocessing

# %%
sc1=preprocessing.StandardScaler()

# %%
print(dir(preprocessing))
# Out:
# ['Binarizer', 'FunctionTransformer', 'KBinsDiscretizer', 'KernelCenterer', 'LabelBinarizer', 'LabelEncoder', 'MaxAbsScaler', 'MinMaxScaler', 'MultiLabelBinarizer', 'Normalizer', 'OneHotEncoder', 'OrdinalEncoder', 'PolynomialFeatures', 'PowerTransformer', 'QuantileTransformer', 'RobustScaler', 'StandardScaler', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '_csr_polynomial_expansion', '_data', '_discretization', '_encoders', '_function_transformer', '_label', 'add_dummy_feature', 'binarize', 'label_binarize', 'maxabs_scale', 'minmax_scale', 'normalize', 'power_transform', 'quantile_transform', 'robust_scale', 'scale']

# %%
sc1
# Out:
# StandardScaler()

# %%
data1=data[4:10]

# %%
data1=data[["Sales","Discount","Order_Quantity","Profit","Shipping_Cost"]]

# %%
data1.head()
# Out:
#         Sales  Discount  Order_Quantity   Profit  Shipping_Cost
# 8177   347.84      0.00              37   -99.25           8.29
# 975    541.47      0.05              49    90.62           4.80
# 5300  1287.94      0.06              37   140.35          14.72
# 7955   733.55      0.07               8   103.13          19.99
# 2506  6553.45      0.03              39  2969.81          19.99

# %%
sc1_d=sc1.fit_transform(data1)
sc1_d
# Out:
# array([[-0.39835511, -1.56095642,  0.78923345, -0.23436287, -0.26348552],
#        [-0.3443415 ,  0.0103268 ,  1.61795077, -0.07568592, -0.46565172],
#        [-0.13611167,  0.32458345,  0.78923345, -0.03412589,  0.10898687],
#        ...,
#        [ 1.68252327, -0.93244313,  1.41077144,  1.23599169,  0.41426363],
#        [-0.45900222, -0.61818648, -1.1444403 , -0.158689  , -0.48245063],
#        [ 1.55029968,  0.63884009,  0.09863568, -0.32464502,  1.28375207]])

# %%
data1.columns
# Out:
# Index(['Sales', 'Discount', 'Order_Quantity', 'Profit', 'Shipping_Cost'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8399 entries, 8177 to 1593
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ord_id               8399 non-null   object
#  1   Prod_id              8399 non-null   object
#  2   Ship_id              8399 non-null   object
#  3   Cust_id              8399 non-null   object
#  4   Sales                8399 non-null   float64
#  5   Discount             8399 non-null   float64
#  6   Order_Quantity       8399 non-null   int64
#  7   Profit               8399 non-null   float64
#  8   Shipping_Cost        8399 non-null   float64
#  9   Product_Base_Margin  8336 non-null   float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 1.0+ MB

# %%
sc1_data=pd.DataFrame(sc1_d,columns=data1.columns)
sc1_data.head()
# Out:
#       Sales  Discount  Order_Quantity    Profit  Shipping_Cost
# 0 -0.398355 -1.560956        0.789233 -0.234363      -0.263486
# 1 -0.344341  0.010327        1.617951 -0.075686      -0.465652
# 2 -0.136112  0.324583        0.789233 -0.034126       0.108987
# 3 -0.290760  0.638840       -1.213500 -0.065231       0.414264
# 4  1.332717 -0.618186        0.927353  2.330492       0.414264

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(5,5))
ax1.set_title("original data")
sns.kdeplot(data1["Sales"],ax=ax1)
sns.kdeplot(data1["Discount"],ax=ax1)
sns.kdeplot(data1["Order_Quantity"],ax=ax1)
sns.kdeplot(data1["Profit"],ax=ax1)
sns.kdeplot(data1["Shipping_Cost"],ax=ax1)
ax2.set_title("standerd scaler")
sns.kdeplot(sc1_data["Sales"],ax=ax2)
sns.kdeplot(sc1_data["Discount"],ax=ax2)
sns.kdeplot(sc1-data["Order_Quantity"],ax=ax2)
sns.kdeplot(sc1_data["Profit"],ax=ax2)
sns.kdeplot(sc1_data["Shipping_Cost"],ax=ax2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     with np.errstate(all="ignore"):
# ---> 68         return op(a, b)
#      69
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\roperator.py in rsub(left, right)
#      12 def rsub(left, right):
# ---> 13     return right - left
#      14
#
# TypeError: unsupported operand type(s) for -: 'StandardScaler' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-123-d08c1d116bf9> in <module>
#      11 sns.kdeplot(sc1_data["Sales"],ax=ax2)
#      12 sns.kdeplot(sc1_data["Discount"],ax=ax2)
# ---> 13 sns.kdeplot(sc1-data["Order_Quantity"],ax=ax2)
#      14 sns.kdeplot(sc1_data["Profit"],ax=ax2)
#      15 sns.kdeplot(sc1_data["Shipping_Cost"],ax=ax2)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#     341         lvalues = extract_array(left, extract_numpy=True)
#     342         rvalues = extract_array(right, extract_numpy=True)
# --> 343         result = arithmetic_op(lvalues, rvalues, op)
#     344
#     345         return left._construct_result(result, name=res_name)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     188     else:
#     189         with np.errstate(all="ignore"):
# --> 190             res_values = na_arithmetic_op(lvalues, rvalues, op)
#     191
#     192     return res_values
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     148             #  will handle complex numbers incorrectly, see GH#32047
#     149             raise
# --> 150         result = masked_arith_op(left, right, op)
#     151
#     152     if is_cmp and (is_scalar(result) or result is NotImplemented):
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in masked_arith_op(x, y, op)
#      94     else:
#      95         if not is_scalar(y):
# ---> 96             raise TypeError(
#      97                 f"Cannot broadcast np.ndarray with operand of type { type(y) }"
#      98             )
#
# TypeError: Cannot broadcast np.ndarray with operand of type <class 'sklearn.preprocessing._data.StandardScaler'>

# %% [markdown]
# #### Robust scalar

# %%
rs=preprocessing.RobustScaler()

# %%
rs_d=rs.fit_transform(data1)
rs_d
# Out:
# array([[-0.06486072, -0.83333333,  0.44      , -0.39725276,  0.20767072],
#        [ 0.05877564,  0.        ,  0.92      ,  0.37437263, -0.11880262],
#        [ 0.53541065,  0.16666667,  0.44      ,  0.5764737 ,  0.80916745],
#        ...,
#        [ 4.69823928, -0.5       ,  0.8       ,  6.7528905 ,  1.30215154],
#        [-0.20368106, -0.33333333, -0.68      , -0.02926056, -0.14593078],
#        [ 4.39558145,  0.33333333,  0.04      , -0.8362831 ,  2.70626754]])

# %%
da=pd.DataFrame(rs_d,columns=data1.columns)
da.head()
# Out:
#       Sales  Discount  Order_Quantity     Profit  Shipping_Cost
# 0 -0.064861 -0.833333            0.44  -0.397253       0.207671
# 1  0.058776  0.000000            0.92   0.374373      -0.118803
# 2  0.535411  0.166667            0.44   0.576474       0.809167
# 3  0.181422  0.333333           -0.72   0.425213       1.302152
# 4  3.897537 -0.333333            0.52  12.075305       1.302152
